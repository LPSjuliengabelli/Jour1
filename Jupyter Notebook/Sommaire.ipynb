# %% [markdown]
# <p style="float: right; margin-left: 20px; margin-right: 100px;">
#   <img src="../Figures/Photo_Qubit.png" width="500">
# </p>
#
# # Lancer les notebooks
#
# - [Simulation du transmon](./Transmon_capacitance.ipynb)
# - [Ligne de transmission](./Ligne_de_transmission.ipynb)
# - [Résonateur](./Transmon_Resonator.ipynb)
# - [Filtre Purcell](./Transmon_Purcell.ipynb)
# - [Mesure dispersive du transmon](./Readout_transmon.ipynb)
